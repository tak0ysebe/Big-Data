# %% [markdown]
# ## Оптимизация выполнения кода, векторизация, Numba

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 3: Оптимизация выполнения кода, векторизация, Numba
# * IPython Cookbook, Second Edition (2018), глава 4
# * https://numba.pydata.org/numba-doc/latest/user/5minguide.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Сгенерируйте массив `A` из `N=1млн` случайных целых чисел на отрезке от 0 до 1000. Пусть `B[i] = A[i] + 100`. Посчитайте среднее значение массива `B`.

# %% [markdown]
# 2. Создайте таблицу 2млн строк и с 4 столбцами, заполненными случайными числами. Добавьте столбец `key`, которые содержит элементы из множества английских букв. Выберите из таблицы подмножество строк, для которых в столбце `key` указаны первые 5 английских букв.

# %% [markdown]
# ## Лабораторная работа 3

# %%
# !pip install line_profiler
# Out:
# Collecting line_profiler
#   Downloading line_profiler-4.0.3-cp39-cp39-win_amd64.whl (83 kB)
# Installing collected packages: line-profiler
# Successfully installed line-profiler-4.0.3

# %%
import pandas as pd
import numpy as np

# %%
recipes = pd.read_csv('recipes_sample.csv')
reviews = pd.read_csv('reviews_sample.csv')
reviews['date'] = pd.to_datetime(reviews['date']) #str to datetime format

# %%
#recipes

# %%
#reviews

# %% [markdown]
# 1. В файлах `recipes_sample.csv` и `reviews_sample.csv` (__ЛР 2__) находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами. Приведите столбцы к нужным типам.
#
# Реализуйте несколько вариантов функции подсчета среднего значения столбца `rating` из таблицы `reviews` для отзывов, оставленных в 2010 году.
#
# A. С использованием метода `DataFrame.iterrows` исходной таблицы;
#
# Б. С использованием метода `DataFrame.iterrows` таблицы, в которой сохранены только отзывы за 2010 год;
#
# В. С использованием метода `Series.mean`.
#
# Проверьте, что результаты работы всех написанных функций корректны и совпадают. Измерьте выполнения всех написанных функций.

# %%
import time

# %%
#A
def mean_rating_A(df):
    total = 0 
    count = 0 
    for _, row in df.iterrows(): #iterrows() - итерация в виде пар (индекс, серия)
        if row['date'].year == 2010:
            total += row['rating']
            count += 1
    return total/count

start_time = time.time() 
mean_rating_A(reviews)         
end_time = time.time()    

execution_time = end_time - start_time
print("Время выполнения функции:", execution_time, "секунд")
mean_rating_A(reviews)
# Out:
# Время выполнения функции: 4.137767553329468 секунд
# 4.4544402182900615

# %%
#B
reviews_2010 = reviews[reviews["date"].dt.year == 2010]

# %%
def mean_rating_B(df):
    total = 0
    count = 0
    for _, row in df.iterrows():
        total += row["rating"]
        count += 1
    return total / count

start_time = time.time() 
mean_rating_B(reviews)         
end_time = time.time()    

execution_time = end_time - start_time
print("Время выполнения функции:", execution_time, "секунд")
mean_rating_B(reviews_2010)
# Out:
# Время выполнения функции: 4.090382814407349 секунд
# 4.4544402182900615

# %%
#C
def mean_rating_C(df):
    return df['rating'].mean()

start_time = time.time() 
mean_rating_C(reviews)         
end_time = time.time()    

execution_time = end_time - start_time
print("Время выполнения функции:", execution_time, "секунд")
mean_rating_C(reviews_2010)
# Out:
# Время выполнения функции: 0.0 секунд
# 4.4544402182900615

# %% [markdown]
# 2. Какая из созданных функций выполняется медленнее? Что наиболее сильно влияет на скорость выполнения? Для ответа использовать профайлер `line_profiler`. Сохраните результаты работы профайлера в отдельную текстовую ячейку и прокомментируйте результаты его работы.
#
# (*). Сможете ли вы ускорить работу функции 1Б, отказавшись от использования метода `iterrows`, но не используя метод `mean`?

# %%
# !pip install line_profiler
# Out:
# Requirement already satisfied: line_profiler in c:\programdata\anaconda3\lib\site-packages (4.0.3)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)

# %%
from line_profiler import LineProfiler
lp = LineProfiler()
lp_wrapper_A = lp(mean_rating_A)
lp_wrapper_B = lp(mean_rating_B)
lp_wrapper_C = lp(mean_rating_C)

lp_wrapper_A(reviews)
lp_wrapper_B(reviews_2010)
lp_wrapper_C(reviews_2010)
lp.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 14.0748 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/1468465748.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2
#      3         1          5.0      5.0      0.0
#      4         1          3.0      3.0      0.0
#      5    126696  124287620.0    981.0     88.3
#      6
#      7    114602   15023941.0    131.1     10.7
#      8     12094    1398805.0    115.7      1.0
#      9     12094      37440.0      3.1      0.0
#     10         1          6.0      6.0      0.0
#
# Total time: 0.0001631 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/3517253749.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2
#      3         1       1631.0   1631.0    100.0
#
# Total time: 1.30347 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/408015298.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1
#      2         1         21.0     21.0      0.0
#      3         1          3.0      3.0      0.0
#      4     12094   11467370.0    948.2     88.0
#      5     12094    1531401.0    126.6     11.7
#      6     12094      35877.0      3.0      0.3
#      7         1          5.0      5.0      0.0

# %%
#оптимизированная ф-ия Б
def mean_rating_newB(df):
    total = reviews_2010["rating"].sum()
    count = reviews_2010["rating"].count()
    return total/count
start_time = time.time() 
mean_rating_newB(reviews)         
end_time = time.time()    

execution_time = end_time - start_time
print("Время выполнения функции:", execution_time, "секунд")
mean_rating_newB(reviews_2010)
# Out:
# Время выполнения функции: 0.0 секунд
# 4.4544402182900615

# %%
lp = LineProfiler()
lp_wrapper_A = lp(mean_rating_A)
lp_wrapper_B = lp(mean_rating_newB)
lp_wrapper_C = lp(mean_rating_C)

lp_wrapper_A(reviews)
lp_wrapper_B(reviews_2010)
lp_wrapper_C(reviews_2010)
lp.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 14.0556 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/1468465748.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2
#      3         1          4.0      4.0      0.0
#      4         1          3.0      3.0      0.0
#      5    126696  124136039.0    979.8     88.3
#      6
#      7    114602   14991865.0    130.8     10.7
#      8     12094    1390983.0    115.0      1.0
#      9     12094      37593.0      3.1      0.0
#     10         1          7.0      7.0      0.0
#
# Total time: 0.0001186 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/3517253749.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2
#      3         1       1186.0   1186.0    100.0
#
# Total time: 0.0004089 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/62112895.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2
#      3         1       3316.0   3316.0     81.1
#      4         1        763.0    763.0     18.7
#      5         1         10.0     10.0      0.2

# %% [markdown]
# 3. Вам предлагается воспользоваться функцией, которая собирает статистику о том, сколько отзывов содержат то или иное слово. Измерьте время выполнения этой функции. Сможете ли вы найти узкие места в коде, используя профайлер? Выпишите (словами), что в имеющемся коде реализовано неоптимально. Оптимизируйте функцию и добейтесь значительного (как минимум, на один порядок) прироста в скорости выполнения.

# %%
def get_word_reviews_count(df):
    word_reviews = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        recipe_id, review = row['recipe_id'], row['review']
        words = review.split(' ')
        for word in words:
            if word not in word_reviews:
                word_reviews[word] = []
            word_reviews[word].append(recipe_id)
    
    word_reviews_count = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        review = row['review']
        words = review.split(' ')
        for word in words:
            word_reviews_count[word] = len(word_reviews[word])
    return word_reviews_count
get_word_reviews_count(reviews)
# Out:
# {'Last': 94,
#  'week': 804,
#  'whole': 5628,
#  'sides': 312,
#  'of': 109029,
#  'frozen': 2647,
#  'salmon': 729,
#  'fillet': 60,
#  'was': 88781,
#  'on': 34583,
#  'sale': 149,
#  'in': 61539,
#  'my': 44144,
#  'local': 561,
#  'supermarket,': 10,
#  'so': 46090,
#  'I': 285147,
#  'bought': 1369,
#  'tons': 161,
#  '(okay,': 5,
#  'only': 13965,
#  '3,': 48,
#  'but': 42513,
#  'total': 381,
#  'weight': 160,
#  'over': 9065,
#  '10': 2303,
#  'pounds).': 2,
#  '': 214145,
#  'This': 39448,
#  'recipe': 41098,
#  'is': 55075,
#  'perfect': 4398,
#  'for': 121224,
#  'fillet,': 14,
#  'even': 7878,
#  'though': 2314,
#  'it': 111175,
#  'calls': 520,
#  'steaks.': 93,
#  'cut': 6688,
#  'up': 13585,
#  'the': 266050,
#  'into': 7031,
#  'individual': 314,
#  'portions': 156,
#  'and': 217849,
#  'followed': 4859,
#  'instructions': 731,
#  'exactly.': 571,
#  "I'm": 7145,
#  'one': 15086,
#  'those': 2287,
#  'food': 2413,
#  'combining': 74,
#  'diets,': 5,
#  'left': 4690,
#  'out': 23644,
#  'white': 3425,
#  'wine': 1256,
#  'added': 21710,
#  'just': 24944,
#  'a': 166136,
#  'dash': 532,
#  'vinegar': 1272,
#  'instead': 10395,
#  '(just': 273,
#  'little': 16319,
#  'bit,': 316,
#  'not': 22907,
#  'enough': 4440,
#  'to': 131471,
#  'change': 4146,
#  'taste': 8026,
#  'dish).': 20,
#  'Super': 840,
#  'yummy,': 366,
#  'leftovers': 1497,
#  'lunch': 1593,
#  'today': 1034,
#  '(lucky': 3,
#  'me)!': 5,
#  'So': 4319,
#  'simple': 3947,
#  'tasty!': 994,
#  'used': 44849,
#  'yellow': 782,
#  'capsicum': 45,
#  'place': 2012,
#  'green': 4470,
#  'because': 11390,
#  "that's": 1563,
#  'what': 7462,
#  'had': 26362,
#  'hand.': 1416,
#  'came': 5263,
#  'together': 3268,
#  'fast.': 178,
#  'Perfect': 755,
#  'meal': 1891,
#  'if': 7326,
#  'you': 24475,
#  "don't": 6183,
#  'have': 35190,
#  'lot': 3186,
#  'time.': 4010,
#  'Easy,': 288,
#  'healthy': 1282,
#  'tasty.': 1986,
#  'Thanks': 26556,
#  'Stardustannie!': 4,
#  'Made': 12801,
#  'PAC': 1488,
#  'Fall': 737,
#  '2007.': 85,
#  'Very': 8691,
#  'nice': 8168,
#  'breakfast': 1398,
#  'HH,': 1,
#  'easy': 17222,
#  'make': 32124,
#  'yummy': 2111,
#  'with': 58374,
#  'fresh': 7670,
#  'hot': 3578,
#  'coffe.': 2,
#  'Instead': 860,
#  'toast': 449,
#  'served': 6449,
#  '#97694': 1,
#  'by': 6592,
#  'Paula': 121,
#  'G': 13,
#  'that': 36984,
#  'made': 38087,
#  'earlier': 167,
#  'turned': 6368,
#  'great.': 3686,
#  'will': 23985,
#  'be': 25032,
#  'regular': 2988,
#  'our': 6879,
#  'house': 1246,
#  '-': 12000,
#  'DH': 3796,
#  'loved': 13755,
#  'them.': 3663,
#  'These': 8371,
#  'are': 15518,
#  'favorite': 2587,
#  'holidays': 123,
#  'children': 356,
#  'We': 12585,
#  'also': 14466,
#  'use': 16905,
#  'Rolo': 6,
#  'candies': 59,
#  'kisses.': 14,
#  'Excellent': 1550,
#  'soup!': 456,
#  'The': 25720,
#  'tomato': 2136,
#  'flavor': 7690,
#  'this': 87057,
#  'freezer': 874,
#  'tag': 808,
#  'soup': 4437,
#  'froze': 645,
#  'beautifully.': 305,
#  'prepared': 935,
#  'as': 35493,
#  'directed': 720,
#  'then': 8440,
#  'allowed': 225,
#  'cool': 953,
#  'container.': 46,
#  'thawed': 211,
#  'fridge': 922,
#  'reheated': 222,
#  'stovetop.': 38,
#  'Worked': 251,
#  'perfectly!': 158,
#  'forgot': 1290,
#  'add': 12987,
#  'skim': 409,
#  'milk': 3759,
#  'still': 6693,
#  'tasted': 4119,
#  'pretty': 3499,
#  'good!': 3887,
#  'Dancer!': 17,
#  'dinner': 3882,
#  'excellent,': 186,
#  'finally': 513,
#  'found': 5067,
#  'tuna': 488,
#  'casserole': 798,
#  'we': 12841,
#  'enjoy,': 11,
#  'thanks.': 123,
#  'When': 1630,
#  'snapped': 9,
#  'picture,': 61,
#  'review': 1142,
#  'recipe.': 14337,
#  'toasted': 775,
#  'pecans': 624,
#  'dish,': 801,
#  'at': 15362,
#  'party': 1243,
#  'Prime': 23,
#  'Rib.': 4,
#  'Ten': 16,
#  'stars': 2070,
#  'Lennie': 29,
#  '!!': 334,
#  'good': 16106,
#  'combination': 1801,
#  'flavors': 2212,
#  'reduce': 910,
#  'rice': 3664,
#  'cilantro': 731,
#  'next': 10082,
#  'time,': 2236,
#  'thanks': 3197,
#  'sharing': 6196,
#  'hon!...Kitten': 9,
#  'Oh': 1335,
#  'Bergy!': 61,
#  'wonderful': 5681,
#  'cakes': 433,
#  'awesome.': 550,
#  'Fast': 83,
#  'put': 8578,
#  'together.': 1445,
#  'get': 6753,
#  'fish': 1128,
#  'where': 971,
#  'live': 435,
#  '(yuck).': 5,
#  'am': 6191,
#  'tired': 147,
#  'trying': 1847,
#  'new': 2765,
#  'recipes': 2819,
#  'help': 761,
#  'lack': 174,
#  'quality.': 62,
#  'But': 2588,
#  'recipe,': 5129,
#  'problem.': 194,
#  'did': 17358,
#  '3': 4472,
#  'cloves': 897,
#  'garlic,': 1029,
#  'seasoned': 776,
#  'bread': 5904,
#  'crumbs': 801,
#  'Smash': 3,
#  'Seasoning(318441).': 1,
#  'It': 19417,
#  'has': 4861,
#  'no': 5863,
#  'salt!\r\nI': 1,
#  'tartar': 77,
#  'sauce': 11425,
#  'go': 3691,
#  '(56860).\r\nThank': 1,
#  'great': 19166,
#  'recipe!': 8487,
#  'very': 25681,
#  'moist': 2457,
#  'cornbread,': 47,
#  'two': 4466,
#  'days': 723,
#  'later.': 237,
#  'less': 3180,
#  'sugar': 6608,
#  'honey,': 203,
#  'farm': 56,
#  'butter...and': 3,
#  'corn,': 222,
#  'about': 12811,
#  '2': 8237,
#  'ears.': 5,
#  'Served': 1974,
#  'ribs': 1203,
#  'grill,': 124,
#  "I've": 5561,
#  'been': 5786,
#  'making': 11030,
#  'past': 418,
#  'several': 1714,
#  'years.': 460,
#  "It's": 2848,
#  'always': 4167,
#  'extremely': 598,
#  'easy!': 923,
#  'posting!': 2469,
#  'generic': 30,
#  'sweetened': 239,
#  'condensed': 231,
#  'works': 748,
#  'well,': 782,
#  'tastes': 2271,
#  'costs': 17,
#  '(I': 2369,
#  'usually': 1911,
#  'Wal-Mart': 3,
#  'brand).': 9,
#  'Exceptional': 7,
#  'delicious': 5729,
#  'make.': 3027,
#  'really': 19400,
#  'liked': 5537,
#  'weekday': 69,
#  'leftover': 1716,
#  'rice.': 1105,
#  'looking': 3050,
#  'different': 3537,
#  'ways': 353,
#  'ground': 2468,
#  'beef.': 346,
#  'love': 9526,
#  'sandwich!!': 10,
#  'alot': 435,
#  'sooo': 594,
#  'Lite': 22,
#  'brown': 3475,
#  'mustard': 1082,
#  'horse': 4,
#  'relish': 159,
#  'some': 20753,
#  'olives': 582,
#  "on's.": 1,
#  'Next': 3485,
#  'time': 17502,
#  'balsamic': 482,
#  'dressing...it': 2,
#  'mind.': 76,
#  ':)': 5164,
#  'cbreezie': 1,
#  'make,': 1286,
#  'affordable': 26,
#  'addicting.': 29,
#  'Our': 363,
#  'household': 66,
#  'it.': 11935,
#  'Blessings': 7,
#  'chef': 292,
#  'sharing.': 2159,
#  'never': 4979,
#  'apple': 1442,
#  'orange': 1633,
#  'juice': 2765,
#  'makes': 3300,
#  'all': 15499,
#  'difference': 673,
#  'texture': 2318,
#  'bread.': 1207,
#  'wonderful!!\r\nThank': 2,
#  'You': 2286,
#  'were': 20716,
#  'delicious!': 3344,
#  'grated': 943,
#  'bit': 9946,
#  'cheddar': 1380,
#  'cheese': 8218,
#  'top': 4343,
#  '5': 4283,
#  'minutes': 5013,
#  'before': 6918,
#  'they': 16863,
#  'done,': 239,
#  'seasoning': 2026,
#  'perfect.': 2023,
#  'best': 4551,
#  'pizza': 955,
#  'dough': 2740,
#  'made!': 190,
#  'Other': 574,
#  'tried': 4438,
#  'machine': 480,
#  'way': 6708,
#  'too': 10530,
#  'sticky.': 81,
#  'Leaving': 11,
#  'msg': 19,
#  'fine.': 946,
#  'divide': 60,
#  'half,': 411,
#  'knead': 90,
#  'floured': 83,
#  'surface': 69,
#  'few': 4897,
#  'times,': 290,
#  'stretch': 74,
#  'cirle.': 1,
#  'like': 20171,
#  'bake': 1806,
#  'cast-iron': 19,
#  'skillet-': 1,
#  'brush': 161,
#  'pan': 3626,
#  'olive': 2058,
#  'oil': 3790,
#  'sprinkle': 635,
#  'corn': 2175,
#  'meal.': 1607,
#  'crust': 1662,
#  '7': 705,
#  '10-15': 75,
#  'lowest': 28,
#  'rack': 265,
#  'oven.': 1053,
#  'saw': 745,
#  'Giada': 8,
#  'Today': 106,
#  'show': 174,
#  'last': 4502,
#  'month': 270,
#  'wanted': 2687,
#  'compare': 104,
#  'family': 7201,
#  'being': 1855,
#  'Marsala': 25,
#  'dry': 2150,
#  'red,': 78,
#  'chicken/turkey': 3,
#  'sausage,': 225,
#  'cutting': 557,
#  'sausages': 113,
#  'finishing': 127,
#  'cooking': 4203,
#  'stove': 565,
#  'My': 14347,
#  'traditionally': 25,
#  'serves': 152,
#  'sausage': 1116,
#  'peppers': 1410,
#  'polenta...this': 1,
#  'compared': 122,
#  'well': 5166,
#  'probably': 2651,
#  'calories': 377,
#  'heats': 11,
#  'kitchen': 520,
#  'summertime!': 2,
#  'meatloaf,': 47,
#  'took': 3830,
#  'reviewers': 587,
#  'suggestion': 524,
#  'another': 4777,
#  'crock': 1034,
#  'pot': 1977,
#  'meatloaf': 395,
#  '(#99616)': 1,
#  'it,': 3813,
#  'sauce,': 1640,
#  'meatloaf.': 109,
#  'sweet': 4938,
#  'tangy': 290,
#  'wonder': 263,
#  'addition.': 273,
#  'again.': 7348,
#  'deliciously': 87,
#  'simple.': 292,
#  'can': 9513,
#  'literally': 148,
#  'thrown': 103,
#  'soups': 203,
#  'i': 7770,
#  'ever': 3856,
#  'had.': 886,
#  'uncomplicated': 6,
#  'taste.': 2042,
#  ',': 715,
#  'from': 12802,
#  'appealed': 20,
#  'me': 7274,
#  'simplicity': 162,
#  'quick': 4068,
#  'could': 6285,
#  'made.': 705,
#  'both': 2697,
#  'flavor.': 3912,
#  'anything': 1423,
#  'see': 2244,
#  'can;': 1,
#  'more': 16840,
#  'substance': 14,
#  'nothing': 718,
#  '(thankfully)': 3,
#  'rustic': 43,
#  'roasted': 1256,
#  'balance': 423,
#  'other': 7016,
#  'ingredients.': 1084,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 109,
#  '1/3': 778,
#  'cup': 7164,
#  'let': 2910,
#  'simmer': 398,
#  'out.': 1223,
#  'would': 16597,
#  'definitly': 60,
#  'much': 12363,
#  'plus': 779,
#  'tea!': 45,
#  'aroma': 300,
#  'tea': 535,
#  'steeping': 10,
#  'five': 663,
#  'minutes,': 843,
#  'wonderful!': 1109,
#  'large': 2093,
#  'glass': 571,
#  'ice': 1500,
#  'enjoyed!': 69,
#  'Good': 1325,
#  'marinade.': 218,
#  'Jack': 169,
#  'Daniels': 23,
#  'exactly': 3583,
#  'except': 2033,
#  "didn't": 14046,
#  'marinate': 353,
#  'quite': 3819,
#  'long.': 221,
#  'hours.': 867,
#  'grilled': 1248,
#  'counter': 137,
#  'grill': 812,
#  'everyone': 2528,
#  'enjoyed': 6746,
#  'Even': 1366,
#  'DH,': 122,
#  'who': 3066,
#  "doesn't": 1810,
#  'beef': 2513,
#  'dressed': 64,
#  'up,': 513,
#  'said': 3122,
#  'Almost': 108,
#  'teriyaki': 96,
#  'baked': 4137,
#  'potato': 1754,
#  'asparagus.': 143,
#  'posting.': 2221,
#  'Fantastic': 361,
#  'earning': 2,
#  'raves': 111,
#  'table.': 201,
#  'Thanks,': 1331,
#  'homegirl!': 5,
#  'comforting.': 50,
#  'low-sodium,': 1,
#  'low-fat': 296,
#  'chicken': 11332,
#  'stock.': 166,
#  'butter.': 945,
#  'dried': 2248,
#  'parsley.': 200,
#  'do': 6861,
#  'than': 10333,
#  'an': 10553,
#  'hour,': 174,
#  'Me': 65,
#  'course.': 92,
#  'Breezermom': 3,
#  'Market': 162,
#  'game': 469,
#  'Easy': 1911,
#  'good.': 7001,
#  'Will': 3432,
#  'again': 7921,
#  'kids': 3123,
#  'weekend,': 54,
#  'your': 6415,
#  'cookies': 1935,
#  'already': 1564,
#  '(your': 4,
#  'Triple': 17,
#  'Chocolates).': 1,
#  "We're": 115,
#  'addicted': 63,
#  'jam': 430,
#  '--': 1634,
#  "it's": 4846,
#  'tend': 205,
#  'vinegar-phobic': 1,
#  'half;': 9,
#  'adore': 101,
#  'black': 1609,
#  'pepper,': 929,
#  'increase': 507,
#  'half.': 567,
#  'Also,': 1561,
#  'once': 1547,
#  'strawberries': 539,
#  'cook': 4212,
#  'down,': 140,
#  'masher': 37,
#  'break': 188,
#  'them': 19689,
#  'consistency.': 287,
#  'pepper': 4401,
#  'kick': 525,
#  'fun,': 59,
#  'English': 151,
#  'muffins,': 161,
#  'peanut': 1356,
#  'butter': 5572,
#  '&': 9664,
#  'jelly': 298,
#  'sandwiches': 473,
#  '(made': 53,
#  'wheat': 1778,
#  'bread.)': 3,
#  'wish': 831,
#  'canning': 142,
#  'store': 1248,
#  'shelf': 48,
#  'it!': 4313,
#  'started': 876,
#  'yesterday': 436,
#  'keep': 2162,
#  'up.': 1429,
#  'back': 3474,
#  'coffee': 976,
#  'figured': 251,
#  'might': 2834,
#  'along': 1572,
#  'benefits.': 12,
#  'OK,': 118,
#  'NEVER': 136,
#  'buy': 1174,
#  'jarred': 130,
#  'terrific!': 129,
#  'early': 259,
#  'day,': 352,
#  'later!': 31,
#  'pizza,': 66,
#  'freezer.': 284,
#  'cant': 183,
#  'wait.': 63,
#  'hint': 419,
#  'spice': 1363,
#  'red': 4424,
#  'omitted': 1607,
#  'flakes': 754,
#  'small': 3035,
#  'delicious.': 3734,
#  'again,': 2053,
#  'tenderness': 27,
#  'rub': 356,
#  'right.': 542,
#  'cold,': 101,
#  'yogurt': 961,
#  'whipped': 834,
#  'in,': 275,
#  'or': 12020,
#  'top.': 1375,
#  'cumin,': 184,
#  'curry,': 57,
#  'cinnamon': 2082,
#  'try': 8937,
#  'Chinese': 203,
#  '5.': 153,
#  "can't": 3022,
#  'resist': 98,
#  'splash': 304,
#  'too!': 1288,
#  '"bake"': 5,
#  'squash': 549,
#  'microwave': 830,
#  '8': 1712,
#  'minute': 545,
#  'blasts': 1,
#  'peel': 343,
#  'when': 9491,
#  'cool,': 89,
#  'freeze': 792,
#  'flesh.': 7,
#  'Carrots': 32,
#  'eaten': 749,
#  'right': 3563,
#  'highly': 529,
#  'recommend': 1542,
#  'these': 14418,
#  'delicious,': 1064,
#  'yet': 1087,
#  'treats!': 27,
#  'plastic': 293,
#  'popsicle': 9,
#  'molds': 10,
#  'store.': 239,
#  'halved': 1284,
#  '16': 340,
#  'popsicles.': 5,
#  'They': 5927,
#  'adults': 195,
#  'gone': 759,
#  'crazy': 379,
#  'eating': 2032,
#  'And': 2587,
#  'since': 4612,
#  "they're": 440,
#  'them!': 817,
#  'Barb': 33,
#  'become': 734,
#  'favorite!': 215,
#  'good,': 3031,
#  'modifications': 131,
#  '(and': 1001,
#  'laziness).': 1,
#  'semi': 81,
#  'breasts,': 185,
#  'browned': 670,
#  'them,': 1125,
#  'stock': 853,
#  'rest': 1884,
#  'through': 1258,
#  'simmer.': 28,
#  'omit': 595,
#  'avoid': 195,
#  'sugary-ness': 1,
#  'commented': 144,
#  'PERFECT.': 35,
#  'As': 1547,
#  'couscous': 179,
#  'anything,': 94,
#  'cold': 1240,
#  'broth': 1953,
#  'soak': 317,
#  'wait': 2103,
#  'breasts': 981,
#  'cook.': 325,
#  'margarine': 312,
#  'garlic-buttery': 1,
#  'certainly': 920,
#  'disappoint).': 1,
#  '#289161.': 1,
#  'Miraklegirl!': 4,
#  'fantastic!': 779,
#  'soft': 1275,
#  'chewy': 397,
#  'loveddd': 1,
#  'friends.': 197,
#  'chopped': 3127,
#  'mars': 2,
#  'bar': 219,
#  'chocolate': 4609,
#  'chips': 1692,
#  'worked': 3075,
#  'charm': 25,
#  'definitely': 6267,
#  'THANKS': 93,
#  'Christmas': 1344,
#  'party!': 71,
#  'Thank': 9735,
#  'treat!': 343,
#  'dressing': 2160,
#  'lot.': 369,
#  'sesame': 650,
#  'seeds': 805,
#  'lamb': 384,
#  'marinaded': 64,
#  'spices.': 376,
#  'posting': 4351,
#  'simply': 738,
#  'WONDERFUL!': 102,
#  'any': 6231,
#  'salt,': 1020,
#  'substitution': 119,
#  "necessity..didn't": 1,
#  'hash': 168,
#  'browns,': 19,
#  'potatoes.': 996,
#  'About': 72,
#  'half': 7891,
#  'peeked': 5,
#  'browning': 302,
#  'bottom': 1067,
#  'potatoes': 3793,
#  "weren't": 511,
#  'cooking.': 721,
#  'needed': 2633,
#  'water.': 897,
#  'DUH!': 1,
#  'remember': 574,
#  'how': 5263,
#  'added,': 81,
#  "I'll": 5414,
#  'redo': 7,
#  'browns': 104,
#  'die': 409,
#  'for....': 2,
#  'truly!': 1,
#  'good..': 25,
#  'it..': 61,
#  'give': 3294,
#  '3.5': 93,
#  'stars.': 688,
#  'okay': 242,
#  'again.<br/><br/>I': 2,
#  'drumsticks': 59,
#  'wings': 425,
#  'grocery': 438,
#  'low': 2407,
#  'sodium': 453,
#  'soy': 1154,
#  'sauce.': 3014,
#  'forget': 241,
#  'marinade': 1074,
#  'chicken.': 1191,
#  'know': 3493,
#  'affected': 64,
#  'thicker.': 86,
#  'barbecue': 199,
#  'move': 69,
#  'fluid.': 6,
#  'thicken': 702,
#  'starch': 190,
#  'flour.': 770,
#  'stated': 531,
#  ':-)': 651,
#  'breakfast!': 170,
#  'mom': 793,
#  'Northern': 39,
#  'Ireland': 14,
#  'introduced': 38,
#  'Marmite': 9,
#  'age': 38,
#  'rye': 150,
#  'marmite': 8,
#  'dip': 1014,
#  'eggs.': 408,
#  'you!': 1483,
#  "Paula's": 14,
#  'Peach': 20,
#  'Dump': 9,
#  'Cake': 198,
#  '#125391': 1,
#  '(only': 110,
#  '4)': 28,
#  'forward': 785,
#  'her': 1377,
#  'call': 572,
#  'future.': 285,
#  'hand': 1526,
#  'dessert': 1009,
#  "'fix'": 2,
#  'table': 454,
#  'short': 442,
#  'notice.': 16,
#  'Wow!': 684,
#  'What': 2588,
#  'amazing': 894,
#  'stuff!': 202,
#  'Hokey': 4,
#  'Pokey': 5,
#  'ice-cream,': 6,
#  'this.\nI': 3,
#  'shocked': 59,
#  'complete': 234,
#  'colour': 105,
#  'after': 5685,
#  'stirring': 211,
#  'baking': 3090,
#  'soda': 304,
#  'through.': 295,
#  'quick.\nI': 1,
#  'burned': 183,
#  'ours': 252,
#  'difficult': 371,
#  'spread': 1079,
#  'flat': 296,
#  'pan,': 648,
#  'first': 6060,
#  'go.\nNext': 1,
#  "what's": 98,
#  'come!': 37,
#  'manual': 7,
#  'method': 625,
#  'directions': 1514,
#  'follow': 830,
#  'produced': 149,
#  'results.': 577,
#  'light': 2557,
#  "za'atar": 11,
#  'topping.': 466,
#  'keeper!': 1322,
#  'Best': 634,
#  '2011': 181,
#  'event,': 33,
#  'recommended': 325,
#  'awalde': 7,
#  'sorry.': 81,
#  "wasn't": 2828,
#  'stretch.': 6,
#  'There': 1134,
#  'something': 3789,
#  'missing': 501,
#  'turn': 1174,
#  'amazing.': 614,
#  'turmeric': 68,
#  'strange': 126,
#  'color': 571,
#  'unappealing.': 7,
#  'smelled': 705,
#  'carne': 7,
#  'asada': 5,
#  'maybe': 2146,
#  'expecting.': 53,
#  'cooked': 6317,
#  'delightful': 259,
#  'while': 3129,
#  'grilling': 225,
#  'meet': 53,
#  'expectations': 42,
#  'served.': 66,
#  'watching': 228,
#  'think': 10740,
#  'tweak': 194,
#  'sure': 5334,
#  'is.': 636,
#  'Did': 453,
#  'Bergy!!': 10,
#  'microwaved': 176,
#  'spuds,': 5,
#  'onions,': 735,
#  'later': 496,
#  'night.': 694,
#  'onion': 3951,
#  'each': 2204,
#  'their': 1558,
#  'flavours': 430,
#  'come': 1545,
#  'distinctly.\r\nGood': 1,
#  'veggie': 655,
#  'dish.': 2670,
#  'Lovely!': 31,
#  'beautiful': 760,
#  'Thanksgiving': 638,
#  'morning.': 386,
#  'With': 666,
#  'link': 42,
#  'sliced': 2056,
#  'fruit': 1048,
#  'enjoy': 1321,
#  'visiting': 112,
#  'grands': 5,
#  'breakfast.': 477,
#  'Kittencal.': 81,
#  'teach': 25,
#  'high': 1257,
#  'school': 333,
#  'foods': 180,
#  'class': 97,
#  'studying': 8,
#  'legumes.': 2,
#  'topping': 1361,
#  'sour': 2563,
#  'cream,': 790,
#  'cheese,': 1367,
#  'Tobasco': 19,
#  'tortilla': 507,
#  'chips.': 630,
#  'While': 418,
#  'making,': 33,
#  'students': 37,
#  'look': 1527,
#  'Not': 1846,
#  'single': 364,
#  'student': 38,
#  '25': 458,
#  'disliked': 19,
#  'students.': 8,
#  'starting': 247,
#  'hour': 1180,
#  'period': 41,
#  'reheating': 45,
#  'day.': 1214,
#  'Many': 181,
#  'requested': 363,
#  'second': 1653,
#  'copy': 147,
#  'take': 2301,
#  'home!': 96,
#  'Great': 5595,
#  'job!': 33,
#  'definately': 1072,
#  'lemon': 3806,
#  'zest': 575,
#  'devine': 17,
#  'reheat': 135,
#  'oven': 3332,
#  ...}

# %%
profile = LineProfiler()
profile.add_function(get_word_reviews_count)
profile.enable()

get_word_reviews_count(reviews)

profile.disable()
profile.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 45.1805 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/3588757971.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1
#      2         1          7.0      7.0      0.0
#      3    126679  134977785.0   1065.5     29.9
#      4    126679   31922283.0    252.0      7.1
#      5    126679    4277274.0     33.8      0.9
#      6   6792010   16698669.0      2.5      3.7
#      7   6617066   23352644.0      3.5      5.2
#      8    174944     745313.0      4.3      0.2
#      9   6792010   29505537.0      4.3      6.5
#     10
#     11         1          5.0      5.0      0.0
#     12    126679  131283921.0   1036.4     29.1
#     13    126679   17362339.0    137.1      3.8
#     14    126679    4219302.0     33.3      0.9
#     15   6792010   17459092.0      2.6      3.9
#     16   6792010   40001110.0      5.9      8.9
#     17         1          3.0      3.0      0.0

# %% [markdown]
# В данном случае можно заметить, что второй цикл проходит по всему DataFrame, выполняя повторные разбиения текста на слова и проверку слов в словаре word_reviews каждый раз. Это неэффективно, особенно если DataFrame содержит много строк.
#
# Для оптимизации можно использовать один цикл, чтобы построить словарь word_reviews и одновременно подсчитать количество отзывов для каждого слова

# %%
from collections import Counter
def get_word_reviews_count_optimized(df):    
    words_counts = Counter()  
    df_without_na = df.dropna(subset=["review"])  
    def update_word_counts(row):        
        if 'recipe_id' in row: 
            words = set(row)            
            words_counts.update(words)  
    pattern = r"[^A-Za-z\s]"  
    df_without_na['review'].str.replace(pattern, "").str.lower().str.split(" ").apply(update_word_counts)   
    return dict(words_counts.items())
# Out:
# {'Last': 94,
#  'week': 804,
#  'whole': 5628,
#  'sides': 312,
#  'of': 109029,
#  'frozen': 2647,
#  'salmon': 729,
#  'fillet': 60,
#  'was': 88781,
#  'on': 34583,
#  'sale': 149,
#  'in': 61539,
#  'my': 44144,
#  'local': 561,
#  'supermarket,': 10,
#  'so': 46090,
#  'I': 285147,
#  'bought': 1369,
#  'tons': 161,
#  '(okay,': 5,
#  'only': 13965,
#  '3,': 48,
#  'but': 42513,
#  'total': 381,
#  'weight': 160,
#  'over': 9065,
#  '10': 2303,
#  'pounds).': 2,
#  '': 214145,
#  'This': 39448,
#  'recipe': 41098,
#  'is': 55075,
#  'perfect': 4398,
#  'for': 121224,
#  'fillet,': 14,
#  'even': 7878,
#  'though': 2314,
#  'it': 111175,
#  'calls': 520,
#  'steaks.': 93,
#  'cut': 6688,
#  'up': 13585,
#  'the': 266050,
#  'into': 7031,
#  'individual': 314,
#  'portions': 156,
#  'and': 217849,
#  'followed': 4859,
#  'instructions': 731,
#  'exactly.': 571,
#  "I'm": 7145,
#  'one': 15086,
#  'those': 2287,
#  'food': 2413,
#  'combining': 74,
#  'diets,': 5,
#  'left': 4690,
#  'out': 23644,
#  'white': 3425,
#  'wine': 1256,
#  'added': 21710,
#  'just': 24944,
#  'a': 166136,
#  'dash': 532,
#  'vinegar': 1272,
#  'instead': 10395,
#  '(just': 273,
#  'little': 16319,
#  'bit,': 316,
#  'not': 22907,
#  'enough': 4440,
#  'to': 131471,
#  'change': 4146,
#  'taste': 8026,
#  'dish).': 20,
#  'Super': 840,
#  'yummy,': 366,
#  'leftovers': 1497,
#  'lunch': 1593,
#  'today': 1034,
#  '(lucky': 3,
#  'me)!': 5,
#  'So': 4319,
#  'simple': 3947,
#  'tasty!': 994,
#  'used': 44849,
#  'yellow': 782,
#  'capsicum': 45,
#  'place': 2012,
#  'green': 4470,
#  'because': 11390,
#  "that's": 1563,
#  'what': 7462,
#  'had': 26362,
#  'hand.': 1416,
#  'came': 5263,
#  'together': 3268,
#  'fast.': 178,
#  'Perfect': 755,
#  'meal': 1891,
#  'if': 7326,
#  'you': 24475,
#  "don't": 6183,
#  'have': 35190,
#  'lot': 3186,
#  'time.': 4010,
#  'Easy,': 288,
#  'healthy': 1282,
#  'tasty.': 1986,
#  'Thanks': 26556,
#  'Stardustannie!': 4,
#  'Made': 12801,
#  'PAC': 1488,
#  'Fall': 737,
#  '2007.': 85,
#  'Very': 8691,
#  'nice': 8168,
#  'breakfast': 1398,
#  'HH,': 1,
#  'easy': 17222,
#  'make': 32124,
#  'yummy': 2111,
#  'with': 58374,
#  'fresh': 7670,
#  'hot': 3578,
#  'coffe.': 2,
#  'Instead': 860,
#  'toast': 449,
#  'served': 6449,
#  '#97694': 1,
#  'by': 6592,
#  'Paula': 121,
#  'G': 13,
#  'that': 36984,
#  'made': 38087,
#  'earlier': 167,
#  'turned': 6368,
#  'great.': 3686,
#  'will': 23985,
#  'be': 25032,
#  'regular': 2988,
#  'our': 6879,
#  'house': 1246,
#  '-': 12000,
#  'DH': 3796,
#  'loved': 13755,
#  'them.': 3663,
#  'These': 8371,
#  'are': 15518,
#  'favorite': 2587,
#  'holidays': 123,
#  'children': 356,
#  'We': 12585,
#  'also': 14466,
#  'use': 16905,
#  'Rolo': 6,
#  'candies': 59,
#  'kisses.': 14,
#  'Excellent': 1550,
#  'soup!': 456,
#  'The': 25720,
#  'tomato': 2136,
#  'flavor': 7690,
#  'this': 87057,
#  'freezer': 874,
#  'tag': 808,
#  'soup': 4437,
#  'froze': 645,
#  'beautifully.': 305,
#  'prepared': 935,
#  'as': 35493,
#  'directed': 720,
#  'then': 8440,
#  'allowed': 225,
#  'cool': 953,
#  'container.': 46,
#  'thawed': 211,
#  'fridge': 922,
#  'reheated': 222,
#  'stovetop.': 38,
#  'Worked': 251,
#  'perfectly!': 158,
#  'forgot': 1290,
#  'add': 12987,
#  'skim': 409,
#  'milk': 3759,
#  'still': 6693,
#  'tasted': 4119,
#  'pretty': 3499,
#  'good!': 3887,
#  'Dancer!': 17,
#  'dinner': 3882,
#  'excellent,': 186,
#  'finally': 513,
#  'found': 5067,
#  'tuna': 488,
#  'casserole': 798,
#  'we': 12841,
#  'enjoy,': 11,
#  'thanks.': 123,
#  'When': 1630,
#  'snapped': 9,
#  'picture,': 61,
#  'review': 1142,
#  'recipe.': 14337,
#  'toasted': 775,
#  'pecans': 624,
#  'dish,': 801,
#  'at': 15362,
#  'party': 1243,
#  'Prime': 23,
#  'Rib.': 4,
#  'Ten': 16,
#  'stars': 2070,
#  'Lennie': 29,
#  '!!': 334,
#  'good': 16106,
#  'combination': 1801,
#  'flavors': 2212,
#  'reduce': 910,
#  'rice': 3664,
#  'cilantro': 731,
#  'next': 10082,
#  'time,': 2236,
#  'thanks': 3197,
#  'sharing': 6196,
#  'hon!...Kitten': 9,
#  'Oh': 1335,
#  'Bergy!': 61,
#  'wonderful': 5681,
#  'cakes': 433,
#  'awesome.': 550,
#  'Fast': 83,
#  'put': 8578,
#  'together.': 1445,
#  'get': 6753,
#  'fish': 1128,
#  'where': 971,
#  'live': 435,
#  '(yuck).': 5,
#  'am': 6191,
#  'tired': 147,
#  'trying': 1847,
#  'new': 2765,
#  'recipes': 2819,
#  'help': 761,
#  'lack': 174,
#  'quality.': 62,
#  'But': 2588,
#  'recipe,': 5129,
#  'problem.': 194,
#  'did': 17358,
#  '3': 4472,
#  'cloves': 897,
#  'garlic,': 1029,
#  'seasoned': 776,
#  'bread': 5904,
#  'crumbs': 801,
#  'Smash': 3,
#  'Seasoning(318441).': 1,
#  'It': 19417,
#  'has': 4861,
#  'no': 5863,
#  'salt!\r\nI': 1,
#  'tartar': 77,
#  'sauce': 11425,
#  'go': 3691,
#  '(56860).\r\nThank': 1,
#  'great': 19166,
#  'recipe!': 8487,
#  'very': 25681,
#  'moist': 2457,
#  'cornbread,': 47,
#  'two': 4466,
#  'days': 723,
#  'later.': 237,
#  'less': 3180,
#  'sugar': 6608,
#  'honey,': 203,
#  'farm': 56,
#  'butter...and': 3,
#  'corn,': 222,
#  'about': 12811,
#  '2': 8237,
#  'ears.': 5,
#  'Served': 1974,
#  'ribs': 1203,
#  'grill,': 124,
#  "I've": 5561,
#  'been': 5786,
#  'making': 11030,
#  'past': 418,
#  'several': 1714,
#  'years.': 460,
#  "It's": 2848,
#  'always': 4167,
#  'extremely': 598,
#  'easy!': 923,
#  'posting!': 2469,
#  'generic': 30,
#  'sweetened': 239,
#  'condensed': 231,
#  'works': 748,
#  'well,': 782,
#  'tastes': 2271,
#  'costs': 17,
#  '(I': 2369,
#  'usually': 1911,
#  'Wal-Mart': 3,
#  'brand).': 9,
#  'Exceptional': 7,
#  'delicious': 5729,
#  'make.': 3027,
#  'really': 19400,
#  'liked': 5537,
#  'weekday': 69,
#  'leftover': 1716,
#  'rice.': 1105,
#  'looking': 3050,
#  'different': 3537,
#  'ways': 353,
#  'ground': 2468,
#  'beef.': 346,
#  'love': 9526,
#  'sandwich!!': 10,
#  'alot': 435,
#  'sooo': 594,
#  'Lite': 22,
#  'brown': 3475,
#  'mustard': 1082,
#  'horse': 4,
#  'relish': 159,
#  'some': 20753,
#  'olives': 582,
#  "on's.": 1,
#  'Next': 3485,
#  'time': 17502,
#  'balsamic': 482,
#  'dressing...it': 2,
#  'mind.': 76,
#  ':)': 5164,
#  'cbreezie': 1,
#  'make,': 1286,
#  'affordable': 26,
#  'addicting.': 29,
#  'Our': 363,
#  'household': 66,
#  'it.': 11935,
#  'Blessings': 7,
#  'chef': 292,
#  'sharing.': 2159,
#  'never': 4979,
#  'apple': 1442,
#  'orange': 1633,
#  'juice': 2765,
#  'makes': 3300,
#  'all': 15499,
#  'difference': 673,
#  'texture': 2318,
#  'bread.': 1207,
#  'wonderful!!\r\nThank': 2,
#  'You': 2286,
#  'were': 20716,
#  'delicious!': 3344,
#  'grated': 943,
#  'bit': 9946,
#  'cheddar': 1380,
#  'cheese': 8218,
#  'top': 4343,
#  '5': 4283,
#  'minutes': 5013,
#  'before': 6918,
#  'they': 16863,
#  'done,': 239,
#  'seasoning': 2026,
#  'perfect.': 2023,
#  'best': 4551,
#  'pizza': 955,
#  'dough': 2740,
#  'made!': 190,
#  'Other': 574,
#  'tried': 4438,
#  'machine': 480,
#  'way': 6708,
#  'too': 10530,
#  'sticky.': 81,
#  'Leaving': 11,
#  'msg': 19,
#  'fine.': 946,
#  'divide': 60,
#  'half,': 411,
#  'knead': 90,
#  'floured': 83,
#  'surface': 69,
#  'few': 4897,
#  'times,': 290,
#  'stretch': 74,
#  'cirle.': 1,
#  'like': 20171,
#  'bake': 1806,
#  'cast-iron': 19,
#  'skillet-': 1,
#  'brush': 161,
#  'pan': 3626,
#  'olive': 2058,
#  'oil': 3790,
#  'sprinkle': 635,
#  'corn': 2175,
#  'meal.': 1607,
#  'crust': 1662,
#  '7': 705,
#  '10-15': 75,
#  'lowest': 28,
#  'rack': 265,
#  'oven.': 1053,
#  'saw': 745,
#  'Giada': 8,
#  'Today': 106,
#  'show': 174,
#  'last': 4502,
#  'month': 270,
#  'wanted': 2687,
#  'compare': 104,
#  'family': 7201,
#  'being': 1855,
#  'Marsala': 25,
#  'dry': 2150,
#  'red,': 78,
#  'chicken/turkey': 3,
#  'sausage,': 225,
#  'cutting': 557,
#  'sausages': 113,
#  'finishing': 127,
#  'cooking': 4203,
#  'stove': 565,
#  'My': 14347,
#  'traditionally': 25,
#  'serves': 152,
#  'sausage': 1116,
#  'peppers': 1410,
#  'polenta...this': 1,
#  'compared': 122,
#  'well': 5166,
#  'probably': 2651,
#  'calories': 377,
#  'heats': 11,
#  'kitchen': 520,
#  'summertime!': 2,
#  'meatloaf,': 47,
#  'took': 3830,
#  'reviewers': 587,
#  'suggestion': 524,
#  'another': 4777,
#  'crock': 1034,
#  'pot': 1977,
#  'meatloaf': 395,
#  '(#99616)': 1,
#  'it,': 3813,
#  'sauce,': 1640,
#  'meatloaf.': 109,
#  'sweet': 4938,
#  'tangy': 290,
#  'wonder': 263,
#  'addition.': 273,
#  'again.': 7348,
#  'deliciously': 87,
#  'simple.': 292,
#  'can': 9513,
#  'literally': 148,
#  'thrown': 103,
#  'soups': 203,
#  'i': 7770,
#  'ever': 3856,
#  'had.': 886,
#  'uncomplicated': 6,
#  'taste.': 2042,
#  ',': 715,
#  'from': 12802,
#  'appealed': 20,
#  'me': 7274,
#  'simplicity': 162,
#  'quick': 4068,
#  'could': 6285,
#  'made.': 705,
#  'both': 2697,
#  'flavor.': 3912,
#  'anything': 1423,
#  'see': 2244,
#  'can;': 1,
#  'more': 16840,
#  'substance': 14,
#  'nothing': 718,
#  '(thankfully)': 3,
#  'rustic': 43,
#  'roasted': 1256,
#  'balance': 423,
#  'other': 7016,
#  'ingredients.': 1084,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 109,
#  '1/3': 778,
#  'cup': 7164,
#  'let': 2910,
#  'simmer': 398,
#  'out.': 1223,
#  'would': 16597,
#  'definitly': 60,
#  'much': 12363,
#  'plus': 779,
#  'tea!': 45,
#  'aroma': 300,
#  'tea': 535,
#  'steeping': 10,
#  'five': 663,
#  'minutes,': 843,
#  'wonderful!': 1109,
#  'large': 2093,
#  'glass': 571,
#  'ice': 1500,
#  'enjoyed!': 69,
#  'Good': 1325,
#  'marinade.': 218,
#  'Jack': 169,
#  'Daniels': 23,
#  'exactly': 3583,
#  'except': 2033,
#  "didn't": 14046,
#  'marinate': 353,
#  'quite': 3819,
#  'long.': 221,
#  'hours.': 867,
#  'grilled': 1248,
#  'counter': 137,
#  'grill': 812,
#  'everyone': 2528,
#  'enjoyed': 6746,
#  'Even': 1366,
#  'DH,': 122,
#  'who': 3066,
#  "doesn't": 1810,
#  'beef': 2513,
#  'dressed': 64,
#  'up,': 513,
#  'said': 3122,
#  'Almost': 108,
#  'teriyaki': 96,
#  'baked': 4137,
#  'potato': 1754,
#  'asparagus.': 143,
#  'posting.': 2221,
#  'Fantastic': 361,
#  'earning': 2,
#  'raves': 111,
#  'table.': 201,
#  'Thanks,': 1331,
#  'homegirl!': 5,
#  'comforting.': 50,
#  'low-sodium,': 1,
#  'low-fat': 296,
#  'chicken': 11332,
#  'stock.': 166,
#  'butter.': 945,
#  'dried': 2248,
#  'parsley.': 200,
#  'do': 6861,
#  'than': 10333,
#  'an': 10553,
#  'hour,': 174,
#  'Me': 65,
#  'course.': 92,
#  'Breezermom': 3,
#  'Market': 162,
#  'game': 469,
#  'Easy': 1911,
#  'good.': 7001,
#  'Will': 3432,
#  'again': 7921,
#  'kids': 3123,
#  'weekend,': 54,
#  'your': 6415,
#  'cookies': 1935,
#  'already': 1564,
#  '(your': 4,
#  'Triple': 17,
#  'Chocolates).': 1,
#  "We're": 115,
#  'addicted': 63,
#  'jam': 430,
#  '--': 1634,
#  "it's": 4846,
#  'tend': 205,
#  'vinegar-phobic': 1,
#  'half;': 9,
#  'adore': 101,
#  'black': 1609,
#  'pepper,': 929,
#  'increase': 507,
#  'half.': 567,
#  'Also,': 1561,
#  'once': 1547,
#  'strawberries': 539,
#  'cook': 4212,
#  'down,': 140,
#  'masher': 37,
#  'break': 188,
#  'them': 19689,
#  'consistency.': 287,
#  'pepper': 4401,
#  'kick': 525,
#  'fun,': 59,
#  'English': 151,
#  'muffins,': 161,
#  'peanut': 1356,
#  'butter': 5572,
#  '&': 9664,
#  'jelly': 298,
#  'sandwiches': 473,
#  '(made': 53,
#  'wheat': 1778,
#  'bread.)': 3,
#  'wish': 831,
#  'canning': 142,
#  'store': 1248,
#  'shelf': 48,
#  'it!': 4313,
#  'started': 876,
#  'yesterday': 436,
#  'keep': 2162,
#  'up.': 1429,
#  'back': 3474,
#  'coffee': 976,
#  'figured': 251,
#  'might': 2834,
#  'along': 1572,
#  'benefits.': 12,
#  'OK,': 118,
#  'NEVER': 136,
#  'buy': 1174,
#  'jarred': 130,
#  'terrific!': 129,
#  'early': 259,
#  'day,': 352,
#  'later!': 31,
#  'pizza,': 66,
#  'freezer.': 284,
#  'cant': 183,
#  'wait.': 63,
#  'hint': 419,
#  'spice': 1363,
#  'red': 4424,
#  'omitted': 1607,
#  'flakes': 754,
#  'small': 3035,
#  'delicious.': 3734,
#  'again,': 2053,
#  'tenderness': 27,
#  'rub': 356,
#  'right.': 542,
#  'cold,': 101,
#  'yogurt': 961,
#  'whipped': 834,
#  'in,': 275,
#  'or': 12020,
#  'top.': 1375,
#  'cumin,': 184,
#  'curry,': 57,
#  'cinnamon': 2082,
#  'try': 8937,
#  'Chinese': 203,
#  '5.': 153,
#  "can't": 3022,
#  'resist': 98,
#  'splash': 304,
#  'too!': 1288,
#  '"bake"': 5,
#  'squash': 549,
#  'microwave': 830,
#  '8': 1712,
#  'minute': 545,
#  'blasts': 1,
#  'peel': 343,
#  'when': 9491,
#  'cool,': 89,
#  'freeze': 792,
#  'flesh.': 7,
#  'Carrots': 32,
#  'eaten': 749,
#  'right': 3563,
#  'highly': 529,
#  'recommend': 1542,
#  'these': 14418,
#  'delicious,': 1064,
#  'yet': 1087,
#  'treats!': 27,
#  'plastic': 293,
#  'popsicle': 9,
#  'molds': 10,
#  'store.': 239,
#  'halved': 1284,
#  '16': 340,
#  'popsicles.': 5,
#  'They': 5927,
#  'adults': 195,
#  'gone': 759,
#  'crazy': 379,
#  'eating': 2032,
#  'And': 2587,
#  'since': 4612,
#  "they're": 440,
#  'them!': 817,
#  'Barb': 33,
#  'become': 734,
#  'favorite!': 215,
#  'good,': 3031,
#  'modifications': 131,
#  '(and': 1001,
#  'laziness).': 1,
#  'semi': 81,
#  'breasts,': 185,
#  'browned': 670,
#  'them,': 1125,
#  'stock': 853,
#  'rest': 1884,
#  'through': 1258,
#  'simmer.': 28,
#  'omit': 595,
#  'avoid': 195,
#  'sugary-ness': 1,
#  'commented': 144,
#  'PERFECT.': 35,
#  'As': 1547,
#  'couscous': 179,
#  'anything,': 94,
#  'cold': 1240,
#  'broth': 1953,
#  'soak': 317,
#  'wait': 2103,
#  'breasts': 981,
#  'cook.': 325,
#  'margarine': 312,
#  'garlic-buttery': 1,
#  'certainly': 920,
#  'disappoint).': 1,
#  '#289161.': 1,
#  'Miraklegirl!': 4,
#  'fantastic!': 779,
#  'soft': 1275,
#  'chewy': 397,
#  'loveddd': 1,
#  'friends.': 197,
#  'chopped': 3127,
#  'mars': 2,
#  'bar': 219,
#  'chocolate': 4609,
#  'chips': 1692,
#  'worked': 3075,
#  'charm': 25,
#  'definitely': 6267,
#  'THANKS': 93,
#  'Christmas': 1344,
#  'party!': 71,
#  'Thank': 9735,
#  'treat!': 343,
#  'dressing': 2160,
#  'lot.': 369,
#  'sesame': 650,
#  'seeds': 805,
#  'lamb': 384,
#  'marinaded': 64,
#  'spices.': 376,
#  'posting': 4351,
#  'simply': 738,
#  'WONDERFUL!': 102,
#  'any': 6231,
#  'salt,': 1020,
#  'substitution': 119,
#  "necessity..didn't": 1,
#  'hash': 168,
#  'browns,': 19,
#  'potatoes.': 996,
#  'About': 72,
#  'half': 7891,
#  'peeked': 5,
#  'browning': 302,
#  'bottom': 1067,
#  'potatoes': 3793,
#  "weren't": 511,
#  'cooking.': 721,
#  'needed': 2633,
#  'water.': 897,
#  'DUH!': 1,
#  'remember': 574,
#  'how': 5263,
#  'added,': 81,
#  "I'll": 5414,
#  'redo': 7,
#  'browns': 104,
#  'die': 409,
#  'for....': 2,
#  'truly!': 1,
#  'good..': 25,
#  'it..': 61,
#  'give': 3294,
#  '3.5': 93,
#  'stars.': 688,
#  'okay': 242,
#  'again.<br/><br/>I': 2,
#  'drumsticks': 59,
#  'wings': 425,
#  'grocery': 438,
#  'low': 2407,
#  'sodium': 453,
#  'soy': 1154,
#  'sauce.': 3014,
#  'forget': 241,
#  'marinade': 1074,
#  'chicken.': 1191,
#  'know': 3493,
#  'affected': 64,
#  'thicker.': 86,
#  'barbecue': 199,
#  'move': 69,
#  'fluid.': 6,
#  'thicken': 702,
#  'starch': 190,
#  'flour.': 770,
#  'stated': 531,
#  ':-)': 651,
#  'breakfast!': 170,
#  'mom': 793,
#  'Northern': 39,
#  'Ireland': 14,
#  'introduced': 38,
#  'Marmite': 9,
#  'age': 38,
#  'rye': 150,
#  'marmite': 8,
#  'dip': 1014,
#  'eggs.': 408,
#  'you!': 1483,
#  "Paula's": 14,
#  'Peach': 20,
#  'Dump': 9,
#  'Cake': 198,
#  '#125391': 1,
#  '(only': 110,
#  '4)': 28,
#  'forward': 785,
#  'her': 1377,
#  'call': 572,
#  'future.': 285,
#  'hand': 1526,
#  'dessert': 1009,
#  "'fix'": 2,
#  'table': 454,
#  'short': 442,
#  'notice.': 16,
#  'Wow!': 684,
#  'What': 2588,
#  'amazing': 894,
#  'stuff!': 202,
#  'Hokey': 4,
#  'Pokey': 5,
#  'ice-cream,': 6,
#  'this.\nI': 3,
#  'shocked': 59,
#  'complete': 234,
#  'colour': 105,
#  'after': 5685,
#  'stirring': 211,
#  'baking': 3090,
#  'soda': 304,
#  'through.': 295,
#  'quick.\nI': 1,
#  'burned': 183,
#  'ours': 252,
#  'difficult': 371,
#  'spread': 1079,
#  'flat': 296,
#  'pan,': 648,
#  'first': 6060,
#  'go.\nNext': 1,
#  "what's": 98,
#  'come!': 37,
#  'manual': 7,
#  'method': 625,
#  'directions': 1514,
#  'follow': 830,
#  'produced': 149,
#  'results.': 577,
#  'light': 2557,
#  "za'atar": 11,
#  'topping.': 466,
#  'keeper!': 1322,
#  'Best': 634,
#  '2011': 181,
#  'event,': 33,
#  'recommended': 325,
#  'awalde': 7,
#  'sorry.': 81,
#  "wasn't": 2828,
#  'stretch.': 6,
#  'There': 1134,
#  'something': 3789,
#  'missing': 501,
#  'turn': 1174,
#  'amazing.': 614,
#  'turmeric': 68,
#  'strange': 126,
#  'color': 571,
#  'unappealing.': 7,
#  'smelled': 705,
#  'carne': 7,
#  'asada': 5,
#  'maybe': 2146,
#  'expecting.': 53,
#  'cooked': 6317,
#  'delightful': 259,
#  'while': 3129,
#  'grilling': 225,
#  'meet': 53,
#  'expectations': 42,
#  'served.': 66,
#  'watching': 228,
#  'think': 10740,
#  'tweak': 194,
#  'sure': 5334,
#  'is.': 636,
#  'Did': 453,
#  'Bergy!!': 10,
#  'microwaved': 176,
#  'spuds,': 5,
#  'onions,': 735,
#  'later': 496,
#  'night.': 694,
#  'onion': 3951,
#  'each': 2204,
#  'their': 1558,
#  'flavours': 430,
#  'come': 1545,
#  'distinctly.\r\nGood': 1,
#  'veggie': 655,
#  'dish.': 2670,
#  'Lovely!': 31,
#  'beautiful': 760,
#  'Thanksgiving': 638,
#  'morning.': 386,
#  'With': 666,
#  'link': 42,
#  'sliced': 2056,
#  'fruit': 1048,
#  'enjoy': 1321,
#  'visiting': 112,
#  'grands': 5,
#  'breakfast.': 477,
#  'Kittencal.': 81,
#  'teach': 25,
#  'high': 1257,
#  'school': 333,
#  'foods': 180,
#  'class': 97,
#  'studying': 8,
#  'legumes.': 2,
#  'topping': 1361,
#  'sour': 2563,
#  'cream,': 790,
#  'cheese,': 1367,
#  'Tobasco': 19,
#  'tortilla': 507,
#  'chips.': 630,
#  'While': 418,
#  'making,': 33,
#  'students': 37,
#  'look': 1527,
#  'Not': 1846,
#  'single': 364,
#  'student': 38,
#  '25': 458,
#  'disliked': 19,
#  'students.': 8,
#  'starting': 247,
#  'hour': 1180,
#  'period': 41,
#  'reheating': 45,
#  'day.': 1214,
#  'Many': 181,
#  'requested': 363,
#  'second': 1653,
#  'copy': 147,
#  'take': 2301,
#  'home!': 96,
#  'Great': 5595,
#  'job!': 33,
#  'definately': 1072,
#  'lemon': 3806,
#  'zest': 575,
#  'devine': 17,
#  'reheat': 135,
#  'oven': 3332,
#  ...}

# %%
profile = LineProfiler()
profile.add_function(get_word_reviews_count_new)
profile.enable()

get_word_reviews_count_new(reviews)

profile.disable()
profile.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 27.3979 s
#
# Could not find file C:\Users\222844\AppData\Local\Temp/ipykernel_9980/2735776033.py
# Are you sure you are running this program from the same directory
# that you ran the profiler from?
# Continuing without the function's contents.
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1
#      2         1          4.0      4.0      0.0
#      3         1          3.0      3.0      0.0
#      4
#      5    126679  133125457.0   1050.9     48.6
#      6    126679   31368753.0    247.6     11.4
#      7    126679    4244442.0     33.5      1.5
#      8   6792010   17136083.0      2.5      6.3
#      9   6617066   22762524.0      3.4      8.3
#     10    174944     698737.0      4.0      0.3
#     11   6792010   30107635.0      4.4     11.0
#     12   6792010   34535058.0      5.1     12.6
#     13
#     14         1          5.0      5.0      0.0

# %% [markdown]
# Разбиение на слова выполняется только один раз перед циклом
# (счетчики уже подсчитываются внутри первого цикла).
#
# Внутри первого цикла, после добавления recipe_id в word_reviews, также выполняется
# инкрементация счетчика word_reviews_count[word].
# Мы используем метод .get(word, 0), чтобы получить текущее значение счетчика для слова word.
# Если слово уже присутствует в словаре word_reviews_count, мы увеличиваем счетчик на 1.
# Если слова еще нет в словаре, устанавливаем начальное значение 0 и затем инкрементируем его.

# %% [markdown]
# 4. Напишите несколько версий функции `MAPE` (см. [MAPE](https://en.wikipedia.org/wiki/Mean_absolute_percentage_error)) для расчета среднего абсолютного процентного отклонения значения рейтинга отзыва на рецепт от среднего значения рейтинга по всем отзывам для этого рецепта.
#     1. Без использования векторизованных операций и методов массивов `numpy` и без использования `numba`
#     2. Без использования векторизованных операций и методов массивов `numpy`, но с использованием `numba`
#     3. С использованием векторизованных операций и методов массивов `numpy`, но без использования `numba`
#     4. C использованием векторизованных операций и методов массивов `numpy` и `numba`
#
# Измерьте время выполнения каждой из реализаций.
#
# Замечание: удалите из выборки отзывы с нулевым рейтингом.

# %%
#Без использования векторизованных операций и методов массивов numpy и без использования numba:
def mape_a(df):
    ratings = [r for r in df['rating'] if r != 0]
    mean_rating = sum(ratings) / len(ratings)
    abs_diff = 0
    for r in ratings:
        abs_diff += abs(r - mean_rating)
    return abs_diff / len(ratings) * 100

start_time = time.time()
result = mape_a(reviews)
execution_time = time.time() - start_time

print("MAPE:", result)
print("Execution Time:", execution_time)
# Out:
# MAPE: 51.64167955430349
# Execution Time: 0.024567604064941406

# %%
# !pip install numba
# Out:
# Requirement already satisfied: numba in c:\programdata\anaconda3\lib\site-packages (0.54.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from numba) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\programdata\anaconda3\lib\site-packages (from numba) (0.37.0)
# Collecting numpy<1.21,>=1.17
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.0
#     Uninstalling numpy-1.22.0:
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Отказано в доступе: 'c:\\programdata\\anaconda3\\lib\\site-packages\\numpy-1.22.0.dist-info\\entry_points.txt'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)

# %%
#Без использования векторизованных операций и методов массивов numpy, но с использованием numba
import numba as nb

@nb.jit
def MAPE_B(df):
    sigma_diff = 0
    mean_rating = sum(df) / len(df)
    for r in df:  
        sigma_diff += abs((r - mean_rating)/r)
    return sigma_diff / len(df) * 100  


start_time = time.time()
REVIEWS=reviews[reviews['rating']!=0]['rating'].values
result = mape_b(REVIEWS)
execution_time = time.time() - start_time

print("MAPE:", result)
print("Execution Time:", execution_time)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9980/1319625297.py in <module>
#       1 #Без использования векторизованных операций и методов массивов numpy, но с использованием numba
# ----> 2 import numba as nb
#       3
#       4 @nb.jit
#       5 def MAPE_B(df):
#
# C:\ProgramData\Anaconda3\lib\site-packages\numba\__init__.py in <module>
#     196
#     197 _ensure_llvm()
# --> 198 _ensure_critical_deps()
#     199
#     200 # we know llvmlite is working as the above tests passed, import it now as SVML
#
# C:\ProgramData\Anaconda3\lib\site-packages\numba\__init__.py in _ensure_critical_deps()
#     136         raise ImportError("Numba needs NumPy 1.17 or greater")
#     137     elif numpy_version > (1, 20):
# --> 138         raise ImportError("Numba needs NumPy 1.20 or less")
#     139
#     140     try:
#
# ImportError: Numba needs NumPy 1.20 or less

# %%
#С использованием векторизованных операций и методов массивов numpy, но без использования numba:

import numpy as np

def mape_c(reviews):
    ratings = np.array([r for r in reviews['rating'] if r != 0])
    mean_rating = np.mean(ratings)
    abs_diff = np.sum(np.abs(ratings - mean_rating))
    return abs_diff / len(ratings) * 100

start_time = time.time()
result = mape_c(reviews)
execution_time = time.time() - start_time

print("MAPE:", result)
print("Execution Time:", execution_time)
# Out:
# MAPE: 51.64167955432964
# Execution Time: 0.014000892639160156

# %%
# C использованием векторизованных операций и методов массивов numpy и numba
import numpy as np
from numba import jit

@jit
def mape_d(ratings):
    mean_rating = np.mean(ratings)
    sigma_diff = np.sum(np.abs((ratings - mean_rating)/ratings))
    return sigma_diff / len(ratings) * 100
ratings = np.array([r for r in reviews['rating'] if r != 0])
mape_d(ratings)

start_time = time.time()
ratings = np.array([r for r in reviews['rating'] if r != 0])
result = mape_d(ratings)
execution_time = time.time() - start_time

print("MAPE:", result)
print("Execution Time:", execution_time)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9980/4083478884.py in <module>
#       1 # C использованием векторизованных операций и методов массивов numpy и numba
#       2 import numpy as np
# ----> 3 from numba import jit
#       4
#       5 @jit
#
# C:\ProgramData\Anaconda3\lib\site-packages\numba\__init__.py in <module>
#     196
#     197 _ensure_llvm()
# --> 198 _ensure_critical_deps()
#     199
#     200 # we know llvmlite is working as the above tests passed, import it now as SVML
#
# C:\ProgramData\Anaconda3\lib\site-packages\numba\__init__.py in _ensure_critical_deps()
#     136         raise ImportError("Numba needs NumPy 1.17 or greater")
#     137     elif numpy_version > (1, 20):
# --> 138         raise ImportError("Numba needs NumPy 1.20 or less")
#     139
#     140     try:
#
# ImportError: Numba needs NumPy 1.20 or less

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1, 3, 4

# %%
# !pip install numpy==1.19.5
# !pip install numba==0.54
# Out:
# Collecting numpy==1.19.5
#   Using cached numpy-1.19.5-cp39-cp39-win_amd64.whl (13.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.0
#     Uninstalling numpy-1.22.0:
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Отказано в доступе: 'c:\\programdata\\anaconda3\\lib\\site-packages\\numpy-1.22.0.dist-info\\entry_points.txt'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# Collecting numba==0.54
#   Using cached numba-0.54.0-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting numpy<1.21,>=1.17
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\programdata\anaconda3\lib\site-packages (from numba==0.54) (0.37.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from numba==0.54) (58.0.4)
# Installing collected packages: numpy, numba
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.0
#     Uninstalling numpy-1.22.0:
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -2mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Отказано в доступе: 'c:\\programdata\\anaconda3\\lib\\site-packages\\numpy-1.22.0.dist-info\\entry_points.txt'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
